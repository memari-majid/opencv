# %% [markdown]
# <a href="https://colab.research.google.com/github/memari-majid/opencv/blob/main/001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Read an image
# * Use the function cv2.imread() to read an image.
# * The image should be in the working directory or a full path of image should be given.
# * Second argument is a flag which specifies the way image should be read.
#  * cv2.IMREAD_COLOR : Loads a color image. Any transparency of
#  * image will be neglected. It is the default flag.
#  * cv2.IMREAD_GRAYSCALE : Loads image in grayscale mode
#  * cv2.IMREAD_UNCHANGED : Loads image as such including alpha channel
# * Instead of these three flags, you can simply pass integers 1, 0 or -1 respectively.

# %%
import numpy as np
import cv2
# Load an color image in grayscale
img = cv2.imread('/content/drive/MyDrive/Notebooks/OpenCV/cat.png',0)

# %% [markdown]
# ### Display an image
# * Use the function cv2.imshow() to display an image in a window. The window automatically fits to the image size.
# * First argument is a window name which is a string. second argument is our image. You can create as many windows as you wish, but with different window names.

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/drive/MyDrive/Notebooks/OpenCV/cat.png', -1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F5B73970450>

# %%
img = cv2.imread('/content/drive/MyDrive/Notebooks/OpenCV/cat.png', 0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F5B7393F890>

# %% [markdown]
# ### Write an image
# * Use the function cv2.imwrite() to save an image.
# * First argument is the file name, second argument is the image you want to save.

# %%
cv2.imwrite('new_cat.jpg',img)
# Out:
# True

# %% [markdown]
# ### Matplotlib
# * Matplotlib is a plotting library for Python which gives you wide variety of plotting methods.
# * You can zoom images, save it etc using Matplotlib.
# * Color image loaded by OpenCV is in BGR mode. But Matplotlib displays in RGB mode.
# * So color images will not be displayed correctly in Matplotlib if image is read with OpenCV. Please see the exercises for more details.

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('/content/drive/MyDrive/Notebooks/OpenCV/cat.png',0)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
